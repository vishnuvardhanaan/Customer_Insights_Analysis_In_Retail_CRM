# %% [markdown]
# # Customer Insights Analysis In Retail CRM

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Importing necessary libraries required for analysis

import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_DCR_cleaned = pd.read_feather(r"F:\Data Science_Projects & Files\Projects\Customer_Insights_Analysis_In_Retail_CRM\Analysis\Output_Data\DCR_cleaned_data.feather")

# %%
sns.countplot(x='visit_frequency', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='visit_frequency', ylabel='count'>

# %%
sns.countplot(x='online_query_comfort', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='online_query_comfort', ylabel='count'>

# %%
sns.countplot(x='resolution_in_new_products', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='resolution_in_new_products', ylabel='count'>

# %%
sns.countplot(x='online_compliant_preference', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='online_compliant_preference', ylabel='count'>

# %%
sns.countplot(x='pre-purchase_research', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='pre-purchase_research', ylabel='count'>

# %%
sns.countplot(x='information_deprivation', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='information_deprivation', ylabel='count'>

# %%
sns.countplot(x='online_compliant_safety', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='online_compliant_safety', ylabel='count'>

# %%
sns.countplot(x='in-person_complaint_issues', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='in-person_complaint_issues', ylabel='count'>

# %%
sns.countplot(x='instant_online_response', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='instant_online_response', ylabel='count'>

# %%
sns.countplot(x='age_group', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %%
sns.countplot(x='gender', data=df_DCR_cleaned)
# Out:
# <Axes: xlabel='gender', ylabel='count'>
